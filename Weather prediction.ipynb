# %%
import pandas as pd

# %%
weatherdata=pd.read_csv("daily_weather.csv")
weatherdata
# Out:
#       number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0          0        918.060000     74.822000              271.100000
# 1          1        917.347688     71.403843              101.935179
# 2          2        923.040000     60.638000               51.000000
# 3          3        920.502751     70.138895              198.832133
# 4          4        921.160000     44.294000              277.800000
# ...      ...               ...           ...                     ...
# 1090    1090        918.900000     63.104000              192.900000
# 1091    1091        918.710000     49.568000              241.600000
# 1092    1092        916.600000     71.096000              189.300000
# 1093    1093        912.600000     58.406000              172.700000
# 1094    1094        921.530000     77.702000               97.100000
#
#       avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# ...

# %%
weatherdata[weatherdata.isnull().any(axis=1)].head(6)
# Out:
#      number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 16       16        917.890000           NaN              169.200000
# 111     111        915.290000     58.820000              182.600000
# 177     177        915.900000           NaN              183.300000
# 262     262        923.596607     58.380598               47.737753
# 277     277        920.480000     62.600000              194.400000
# 334     334        916.230000     75.740000              149.100000
#
#      avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 16             2.192201              196.800000            2.930391
# 111           15.613841              189.000000                 NaN
# 177            4.719943              189.900000            5.346287
# 262           10.636273               67.145843           13.671423
# 277            2.751436                     NaN            3.869906
# 334            2.751436              187.500000            4.183078
#
# ...

# %%
del weatherdata["number"]
weatherdata
# Out:
#       air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0           918.060000     74.822000              271.100000
# 1           917.347688     71.403843              101.935179
# 2           923.040000     60.638000               51.000000
# 3           920.502751     70.138895              198.832133
# 4           921.160000     44.294000              277.800000
# ...                ...           ...                     ...
# 1090        918.900000     63.104000              192.900000
# 1091        918.710000     49.568000              241.600000
# 1092        916.600000     71.096000              189.300000
# 1093        912.600000     58.406000              172.700000
# 1094        921.530000     77.702000               97.100000
#
#       avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 0               2.080354              295.400000            2.863283
# 1               2.443009              140.471548            3.533324
# ...

# %%
weatherdata.shape[0]
# Out:
# 1095

# %%
weatherdata=weatherdata.dropna()

# %%
weatherdata.shape[0]
# Out:
# 1064

# %%
clean_weatherdata = weatherdata.copy()
clean_weatherdata['high_humidity_label'] = (clean_weatherdata['relative_humidity_3pm'] >24.99) *1
clean_weatherdata['high_humidity_label'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: high_humidity_label, dtype: int32

# %%
Y=clean_weatherdata['high_humidity_label']
print(Y)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1090    1
# 1091    1
# 1092    1
# 1093    1
# 1094    0
# Name: high_humidity_label, Length: 1064, dtype: int32

# %%
clean_weatherdata.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am',
#        'relative_humidity_3pm', 'high_humidity_label'],
#       dtype='object')

# %%
m=['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
       'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
       'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am']

# %%
X=clean_weatherdata[m]
X
# Out:
#       air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0           918.060000     74.822000              271.100000
# 1           917.347688     71.403843              101.935179
# 2           923.040000     60.638000               51.000000
# 3           920.502751     70.138895              198.832133
# 4           921.160000     44.294000              277.800000
# ...                ...           ...                     ...
# 1090        918.900000     63.104000              192.900000
# 1091        918.710000     49.568000              241.600000
# 1092        916.600000     71.096000              189.300000
# 1093        912.600000     58.406000              172.700000
# 1094        921.530000     77.702000               97.100000
#
#       avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 0               2.080354              295.400000            2.863283
# 1               2.443009              140.471548            3.533324
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.21,random_state=324)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_leaf_nodes=30,random_state=0)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=30, random_state=0)

# %%
from sklearn.metrics import accuracy_score
model_predictiony=model.predict(x_test)
model_predictiony[0:9]
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0, 1])

# %%
y_test[0:9]
# Out:
# 456    0
# 845    0
# 693    1
# 259    1
# 723    1
# 224    1
# 300    1
# 442    0
# 585    1
# Name: high_humidity_label, dtype: int32

# %%
score=accuracy_score(y_test,model_predictiony)*100
print("Accuracy of the model is :",score)
# Out:
# Accuracy of the model is : 91.07142857142857
